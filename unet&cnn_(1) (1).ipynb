# %%
import zipfile

zip_path = "/content/archive (5).zip"
extract_path = "/content/archive (5)"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction Done!")
# Out:
# Extraction Done!

# %%
import os
for root, dirs, files in os.walk("/content/archive (5)/DATASET"):
    print(f"{root} → {len(files)} files")
# Out:
# /content/archive (5)/DATASET → 0 files
# /content/archive (5)/DATASET/classification → 0 files
# /content/archive (5)/DATASET/classification/Training → 0 files
# /content/archive (5)/DATASET/classification/Training/meningioma → 1339 files
# /content/archive (5)/DATASET/classification/Training/notumor → 1595 files
# /content/archive (5)/DATASET/classification/Training/glioma → 1321 files
# /content/archive (5)/DATASET/classification/Training/pituitary → 1457 files
# /content/archive (5)/DATASET/classification/Testing → 0 files
# /content/archive (5)/DATASET/classification/Testing/meningioma → 306 files
# /content/archive (5)/DATASET/classification/Testing/notumor → 405 files
# /content/archive (5)/DATASET/classification/Testing/glioma → 300 files
# /content/archive (5)/DATASET/classification/Testing/pituitary → 300 files
# /content/archive (5)/DATASET/Segmentation → 0 files
# /content/archive (5)/DATASET/Segmentation/Pituitary tumor → 1860 files
# /content/archive (5)/DATASET/Segmentation/Meningioma → 1416 files
# /content/archive (5)/DATASET/Segmentation/Glioma → 1108 files

# %% [markdown]
# # UNET

# %%
import os

main_path  = "/content/archive (5)/DATASET/Segmentation/"

seg_classes = ['Glioma','Meningioma','Pituitary tumor']
SEG_IMG_SIZE = 256

# %%
def add_mask(x):
    nsplit = x.split('.')
    fname = nsplit[0] + '_mask.' + nsplit[1]
    return fname

dict_aux = {'filepath':[],'label':[],'encoded_label':[]}
for c in seg_classes:
    class_path = os.path.join(main_path,c)
    encoded_label = seg_classes.index(c) #Match the id from the classification model above
    for fn in os.listdir(class_path):
        dict_aux['filepath'].append( os.path.join(class_path,fn) )
        dict_aux['label'].append(c)
        dict_aux['encoded_label'].append(encoded_label)

seg_df = pd.DataFrame(dict_aux)
seg_df = seg_df.loc[ ~seg_df.filepath.str.contains('_mask')].copy()
seg_df.reset_index(inplace=True)
seg_df['maskpath'] = seg_df.filepath.apply(add_mask)
seg_df = seg_df.sample(frac=1)

# %%
train_seg, test_seg = train_test_split(seg_df,test_size=0.15,random_state=99)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.countplot(x = train_seg.label)
plt.title('Train classes balance')

plt.subplot(1,2,2)
sns.countplot(x = test_seg.label)
plt.title('Test classes balance')

plt.tight_layout()
plt.show()

# %%
len(test_seg),len(train_seg)
# Out:
# (329, 1863)

# %%
train_paths_input = train_seg.filepath.tolist()
train_paths_output = train_seg.maskpath.tolist()
train_classes_seg = train_seg.encoded_label.tolist()

test_paths_input = test_seg.filepath.tolist()
test_paths_output = test_seg.maskpath.tolist()
test_classes_seg = test_seg.encoded_label.tolist()

# %%
def load_and_preprocess_image_seg(input_path_, output_path_, training=True):
    input_image = tf.io.read_file(input_path_)
    output_image = tf.io.read_file(output_path_)

    input_image = tf.image.decode_png(input_image,channels=1)
    output_image = tf.image.decode_png(output_image,channels=1)

    input_image = tf.cast(input_image, tf.float32) / 255.0
    output_image = tf.cast(output_image, tf.float32) / 255.0

    if training:
       input_image,output_image = augment_image_seg(input_image,output_image)

    input_image = tf.image.resize(input_image, [SEG_IMG_SIZE, SEG_IMG_SIZE])
    output_image = tf.image.resize(output_image, [SEG_IMG_SIZE, SEG_IMG_SIZE])
        #Binarize mask after resizing
    output_image = tf.cast(output_image > 0.15, tf.float32)

    return input_image,output_image

def augment_image_seg(input_image,output_image):
    if tf.random.uniform([]) > 0.5:
        input_image = tf.image.flip_left_right(input_image)
        output_image = tf.image.flip_left_right(output_image)
    if tf.random.uniform([]) > 0.5:
        input_image = tf.image.flip_up_down(input_image)
        output_image = tf.image.flip_up_down(output_image)
    if tf.random.uniform([]) > 0.5:
        k_rot = tf.random.uniform([],minval=1,maxval=4,dtype=tf.int32)
        input_image = tf.image.rot90(input_image,k=k_rot)
        output_image = tf.image.rot90(output_image,k=k_rot)
    return input_image,output_image

# %%
BATCH_SIZE = 16#32

train_ds_seg = tf.data.Dataset.from_tensor_slices((train_paths_input, train_paths_output))
train_ds_seg = train_ds_seg.map(
    lambda x, y: load_and_preprocess_image_seg(x, y, training=True),
    num_parallel_calls=tf.data.AUTOTUNE
)
train_ds_seg = train_ds_seg.shuffle(buffer_size=1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

test_ds_seg = tf.data.Dataset.from_tensor_slices((test_paths_input, test_paths_output))
test_ds_seg = test_ds_seg.map(
    lambda x, y: load_and_preprocess_image_seg(x, y, training=False),
    num_parallel_calls=tf.data.AUTOTUNE
)
test_ds_seg = test_ds_seg.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
inputs = Input((SEG_IMG_SIZE,SEG_IMG_SIZE,1))

# Encoder (Downsampling)
c1 = Conv2D(32, 3, activation='relu', padding='same')(inputs)
c1 = Conv2D(32, 3, activation='relu', padding='same')(c1)
p1 = MaxPool2D()(c1)

c2 = Conv2D(64, 3, activation='relu', padding='same')(p1)
c2 = Conv2D(64, 3, activation='relu', padding='same')(c2)
p2 = MaxPool2D()(c2)

c3 = Conv2D(128, 3, activation='relu', padding='same')(p2)
c3 = Conv2D(128, 3, activation='relu', padding='same')(c3)
p3 = MaxPool2D()(c3)

c4 = Conv2D(256, 3, activation='relu', padding='same')(p3)
c4 = Conv2D(256, 3, activation='relu', padding='same')(c4)
p4 = MaxPool2D()(c4)

# Bottleneck
c5 = Conv2D(512, 3, activation='relu', padding='same')(p4)
c5 = Conv2D(512, 3, activation='relu', padding='same')(c5)

# Decoder (Upsampling)
u6 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(256, 3, activation='relu', padding='same')(u6)
c6 = Conv2D(256, 3, activation='relu', padding='same')(c6)

u7 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(128, 3, activation='relu', padding='same')(u7)
c7 = Conv2D(128, 3, activation='relu', padding='same')(c7)

u8 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(64, 3, activation='relu', padding='same')(u8)
c8 = Conv2D(64, 3, activation='relu', padding='same')(c8)


u9 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(32, 3, activation='relu', padding='same')(u9)
c9 = Conv2D(32, 3, activation='relu', padding='same')(c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

model_seg = Model(inputs=[inputs], outputs=[outputs])
model_seg.compile(optimizer = Adam(learning_rate=0.001), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "/content/unet_best.keras",  # ✅ changed from .h5
        save_best_only=True
    )
]

# %%
model_seg.fit(train_ds_seg,validation_data=test_ds_seg, epochs = 45, callbacks=callbacks)
# Out:
# Epoch 1/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 131s 682ms/step - accuracy: 0.9746 - loss: 0.1358 - val_accuracy: 0.9819 - val_loss: 0.0759
# Epoch 2/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 43s 312ms/step - accuracy: 0.9831 - loss: 0.0707 - val_accuracy: 0.9819 - val_loss: 0.0723
# Epoch 3/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 307ms/step - accuracy: 0.9831 - loss: 0.0663 - val_accuracy: 0.9819 - val_loss: 0.0700
# Epoch 4/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 303ms/step - accuracy: 0.9831 - loss: 0.0618 - val_accuracy: 0.9819 - val_loss: 0.0724
# Epoch 5/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 43s 309ms/step - accuracy: 0.9831 - loss: 0.0620 - val_accuracy: 0.9819 - val_loss: 0.0685
# Epoch 6/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 307ms/step - accuracy: 0.9831 - loss: 0.0571 - val_accuracy: 0.9819 - val_loss: 0.0578
# Epoch 7/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 313ms/step - accuracy: 0.9831 - loss: 0.0534 - val_accuracy: 0.9819 - val_loss: 0.0562
# Epoch 8/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 43s 308ms/step - accuracy: 0.9834 - loss: 0.0510 - val_accuracy: 0.9831 - val_loss: 0.0505
# Epoch 9/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 82s 313ms/step - accuracy: 0.9839 - loss: 0.0487 - val_accuracy: 0.9831 - val_loss: 0.0504
# Epoch 10/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 305ms/step - accuracy: 0.9840 - loss: 0.0481 - val_accuracy: 0.9839 - val_loss: 0.0463
# Epoch 11/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 313ms/step - accuracy: 0.9849 - loss: 0.0451 - val_accuracy: 0.9848 - val_loss: 0.0437
# Epoch 12/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 43s 307ms/step - accuracy: 0.9855 - loss: 0.0423 - val_accuracy: 0.9846 - val_loss: 0.0429
# Epoch 13/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 83s 316ms/step - accuracy: 0.9865 - loss: 0.0388 - val_accuracy: 0.9857 - val_loss: 0.0408
# Epoch 14/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 81s 315ms/step - accuracy: 0.9870 - loss: 0.0370 - val_accuracy: 0.9866 - val_loss: 0.0394
# Epoch 15/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 43s 312ms/step - accuracy: 0.9877 - loss: 0.0348 - val_accuracy: 0.9872 - val_loss: 0.0377
# Epoch 16/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 304ms/step - accuracy: 0.9882 - loss: 0.0336 - val_accuracy: 0.9865 - val_loss: 0.0438
# Epoch 17/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 307ms/step - accuracy: 0.9889 - loss: 0.0321 - val_accuracy: 0.9881 - val_loss: 0.0341
# Epoch 18/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 80s 306ms/step - accuracy: 0.9896 - loss: 0.0287 - val_accuracy: 0.9884 - val_loss: 0.0341
# Epoch 19/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 306ms/step - accuracy: 0.9899 - loss: 0.0281 - val_accuracy: 0.9885 - val_loss: 0.0317
# Epoch 20/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 82s 311ms/step - accuracy: 0.9908 - loss: 0.0255 - val_accuracy: 0.9891 - val_loss: 0.0298
# Epoch 21/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 305ms/step - accuracy: 0.9910 - loss: 0.0241 - val_accuracy: 0.9898 - val_loss: 0.0281
# Epoch 22/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 303ms/step - accuracy: 0.9916 - loss: 0.0224 - val_accuracy: 0.9891 - val_loss: 0.0327
# Epoch 23/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 43s 308ms/step - accuracy: 0.9920 - loss: 0.0217 - val_accuracy: 0.9892 - val_loss: 0.0316
# Epoch 24/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 80s 305ms/step - accuracy: 0.9923 - loss: 0.0211 - val_accuracy: 0.9891 - val_loss: 0.0297
# Epoch 25/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 305ms/step - accuracy: 0.9928 - loss: 0.0191 - val_accuracy: 0.9900 - val_loss: 0.0290
# Epoch 26/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 302ms/step - accuracy: 0.9933 - loss: 0.0176 - val_accuracy: 0.9898 - val_loss: 0.0289
# Epoch 27/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 305ms/step - accuracy: 0.9936 - loss: 0.0172 - val_accuracy: 0.9903 - val_loss: 0.0276
# Epoch 28/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 307ms/step - accuracy: 0.9929 - loss: 0.0189 - val_accuracy: 0.9904 - val_loss: 0.0300
# Epoch 29/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 82s 316ms/step - accuracy: 0.9943 - loss: 0.0151 - val_accuracy: 0.9906 - val_loss: 0.0274
# Epoch 30/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 301ms/step - accuracy: 0.9945 - loss: 0.0143 - val_accuracy: 0.9905 - val_loss: 0.0315
# Epoch 31/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 312ms/step - accuracy: 0.9950 - loss: 0.0128 - val_accuracy: 0.9908 - val_loss: 0.0269
# Epoch 32/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 306ms/step - accuracy: 0.9951 - loss: 0.0126 - val_accuracy: 0.9904 - val_loss: 0.0333
# Epoch 33/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 301ms/step - accuracy: 0.9954 - loss: 0.0121 - val_accuracy: 0.9911 - val_loss: 0.0315
# Epoch 34/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 302ms/step - accuracy: 0.9952 - loss: 0.0124 - val_accuracy: 0.9902 - val_loss: 0.0339
# Epoch 35/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 303ms/step - accuracy: 0.9947 - loss: 0.0142 - val_accuracy: 0.9900 - val_loss: 0.0330
# Epoch 36/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 81s 304ms/step - accuracy: 0.9954 - loss: 0.0119 - val_accuracy: 0.9905 - val_loss: 0.0469
# Epoch 37/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 307ms/step - accuracy: 0.9956 - loss: 0.0113 - val_accuracy: 0.9913 - val_loss: 0.0295
# Epoch 38/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 308ms/step - accuracy: 0.9962 - loss: 0.0097 - val_accuracy: 0.9908 - val_loss: 0.0321
# Epoch 39/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 302ms/step - accuracy: 0.9963 - loss: 0.0092 - val_accuracy: 0.9913 - val_loss: 0.0308
# Epoch 40/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 306ms/step - accuracy: 0.9962 - loss: 0.0097 - val_accuracy: 0.9906 - val_loss: 0.0437
# Epoch 41/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 81s 305ms/step - accuracy: 0.9963 - loss: 0.0093 - val_accuracy: 0.9912 - val_loss: 0.0390
# Epoch 42/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 303ms/step - accuracy: 0.9967 - loss: 0.0084 - val_accuracy: 0.9912 - val_loss: 0.0313
# Epoch 43/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 83s 310ms/step - accuracy: 0.9967 - loss: 0.0081 - val_accuracy: 0.9906 - val_loss: 0.0409
# Epoch 44/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 41s 306ms/step - accuracy: 0.9957 - loss: 0.0113 - val_accuracy: 0.9903 - val_loss: 0.0385
# Epoch 45/45
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 42s 313ms/step - accuracy: 0.9967 - loss: 0.0083 - val_accuracy: 0.9905 - val_loss: 0.0382

# %%
y_pred = model_seg.predict(test_ds_seg)
y_pred = (y_pred > 0.5).astype(np.uint8)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 196ms/step

# %%
y_true = []
for _, y_true_ in test_ds_seg:
    y_true.append(y_true_.numpy())
y_true = np.concatenate(y_true, axis=0)  # single NumPy array

# %%
f1_score(y_true.flatten(), y_pred.flatten())
# Out:
# 0.6990293251826512

# %%
accuracy_score(y_true.flatten(), y_pred.flatten())
# Out:
# 0.9904642771804949

# %%
confusion_matrix(y_true.flatten(), y_pred.flatten())
# Out:
# array([[21116976,    54884],
#        [  150719,   238765]])

# %%
def visualize_results(n,source='test'):
    for _ in range(n):
        if source == 'test':
            img_input_paths = test_paths_input
            img_output_paths = test_paths_output
            type_labels = test_classes_seg
        else:
            img_input_paths = train_paths_input
            img_output_paths = train_paths_output
            type_labels = train_classes_seg

        img_pick = random.randint(0,len(img_input_paths)-1)

        img_input_path = img_input_paths[img_pick]
        img_output_path = img_output_paths[img_pick]
        type_label = type_labels[img_pick]

        img_inp,img_out = load_and_preprocess_image_seg(img_input_path, img_output_path, training=False)
        img_inp = tf.expand_dims(img_inp, axis=0)
        img_pred = model_seg.predict(img_inp)
        img_pred_bin = (img_pred[0] > 0.5).astype(np.uint8)


        plt.figure(figsize=(10,5))
        plt.subplot(1,3,1)
        plt.title(f'Original image {classes[type_label]}')
        plt.imshow(img_inp[0],cmap='gray')
        plt.grid(False)
        plt.axis('off')

        plt.subplot(1,3,2)
        plt.imshow(img_inp[0],cmap='gray')
        plt.imshow(img_out,cmap='Reds',alpha=img_out[:,:,0]/2)
        plt.grid(False)
        plt.axis('off')
        plt.title(f'Expected area detection')

        plt.subplot(1,3,3)
        plt.imshow(img_inp[0],cmap='gray')
        plt.imshow(img_pred_bin,cmap='Reds',alpha=img_pred_bin[:,:,0]/2)
        plt.grid(False)
        plt.axis('off')
        plt.title(f'Area detected')

        plt.tight_layout()
        plt.show()

# %%
visualize_results(3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %% [markdown]
# ✔ Skip connections → retain tumor boundaries
#
# ✔ Deep bottleneck → strong feature extraction
#
# ✔ Sigmoid → binary mask output

# %% [markdown]
# # CNN CLASSIFICATION

# %% [markdown]
# STEP 5.1: DEFINE PATHS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from PIL import Image

from tensorflow.keras.layers import Conv2D,MaxPool2D,Flatten,Dense,UpSampling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential,load_model

#U-net only
from tensorflow.keras.layers import Input,Conv2DTranspose,concatenate
from tensorflow.keras.models import Model

import tensorflow as tf

import numpy as np
from sklearn.metrics import accuracy_score,confusion_matrix,f1_score
from sklearn.model_selection import train_test_split
import random

# %%
train_dir = "/content/archive (5)/DATASET/classification/Training"
test_dir = "/content/archive (5)/DATASET/classification/Testing"
classes = ['glioma','meningioma','pituitary','notumor']
RED_IMG_SIZE = 128
ORIG_IMG_SIZE = 512
seed = 99
tf.random.set_seed(seed)
#random.seed(seed)
np.random.seed(seed)

# %%
def generate_dataframe(dir):
    dict_aux = { 'filedir':[],'label':[]}#,'width':[],'height':[] }
    for c in classes:
        class_dir = os.path.join(dir,c)
        for file_name in os.listdir(class_dir):
            filedir = os.path.join(class_dir,file_name)
            dict_aux['filedir'].append(  filedir )
            dict_aux['label'].append(c)

            # img = Image.open(filedir)
            # dict['width'] = img.width
            # dict['height'] = img.height

    df = pd.DataFrame(dict_aux)
    df = df.sample(frac=1)
    df.reset_index(inplace=True)
    return df

# %%
train_df = generate_dataframe(train_dir)
test_df = generate_dataframe(test_dir)

# %%
train_df.info(),test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5712 entries, 0 to 5711
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    5712 non-null   int64
#  1   filedir  5712 non-null   object
#  2   label    5712 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 134.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1311 entries, 0 to 1310
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    1311 non-null   int64
#  1   filedir  1311 non-null   object
#  2   label    1311 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 30.9+ KB
# (None, None)

# %%
train_df.sample(5)
# Out:
#       index                                            filedir    label
# 5469   1265  /content/archive (5)/DATASET/classification/Tr...   glioma
# 1715   5233  /content/archive (5)/DATASET/classification/Tr...  notumor
# 4721   5263  /content/archive (5)/DATASET/classification/Tr...  notumor
# 331    4929  /content/archive (5)/DATASET/classification/Tr...  notumor
# 1272    394  /content/archive (5)/DATASET/classification/Tr...   glioma

# %%
test_df.sample(5)
# Out:
#       index                                            filedir       label
# 1072   1075  /content/archive (5)/DATASET/classification/Te...     notumor
# 135     337  /content/archive (5)/DATASET/classification/Te...  meningioma
# 45      947  /content/archive (5)/DATASET/classification/Te...     notumor
# 1029    746  /content/archive (5)/DATASET/classification/Te...   pituitary
# 631     233  /content/archive (5)/DATASET/classification/Te...      glioma

# %%
train_df.isna().any().any(),test_df.isna().any().any()
# Out:
# (np.False_, np.False_)

# %%
train_df.filedir.duplicated().any(),test_df.filedir.duplicated().any()
# Out:
# (np.False_, np.False_)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.countplot(x = train_df.label)
plt.title('Train classes balance')

plt.subplot(1,2,2)
sns.countplot(x = test_df.label)
plt.title('Test classes balance')

plt.tight_layout()
plt.show()

# %%
train_df = pd.concat([train_df,pd.get_dummies(train_df.label).astype(int)[classes]],axis=1)
test_df = pd.concat([test_df,pd.get_dummies(test_df.label).astype(int)[classes]],axis=1)

# %%
train_df.sample(5)
# Out:
#       index                                            filedir       label  \
# 3345   1098  /content/archive (5)/DATASET/classification/Tr...      glioma
# 4085   2502  /content/archive (5)/DATASET/classification/Tr...  meningioma
# 4483   1150  /content/archive (5)/DATASET/classification/Tr...      glioma
# 3724   4697  /content/archive (5)/DATASET/classification/Tr...     notumor
# 4563    214  /content/archive (5)/DATASET/classification/Tr...      glioma
#
#       glioma  meningioma  pituitary  notumor
# 3345       1           0          0        0
# 4085       0           1          0        0
# 4483       1           0          0        0
# 3724       0           0          0        1
# 4563       1           0          0        0

# %%
test_df.sample(5)
# Out:
#       index                                            filedir      label  \
# 1085     21  /content/archive (5)/DATASET/classification/Te...     glioma
# 439    1176  /content/archive (5)/DATASET/classification/Te...    notumor
# 64      953  /content/archive (5)/DATASET/classification/Te...    notumor
# 728     854  /content/archive (5)/DATASET/classification/Te...  pituitary
# 722    1001  /content/archive (5)/DATASET/classification/Te...    notumor
#
#       glioma  meningioma  pituitary  notumor
# 1085       1           0          0        0
# 439        0           0          0        1
# 64         0           0          0        1
# 728        0           0          1        0
# 722        0           0          0        1

# %%
len(train_df),len(test_df)
# Out:
# (5712, 1311)

# %%
train_paths = train_df.filedir.tolist()
train_labels = train_df[classes].values

test_paths = test_df.filedir.tolist()
test_labels = test_df[classes].values

# %%
def load_and_preprocess_image(path, label, training=True):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image, channels=1)
    image = tf.cast(image, tf.float32) / 255.0
    if training:
        image = augment_image(image)
    image = tf.image.resize(image, [RED_IMG_SIZE, RED_IMG_SIZE])
    return image,label

def augment_image(image, ):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    if tf.random.uniform([]) > 0.5:
        image = tf.image.rot90(image,k=tf.random.uniform([],minval=1,maxval=4,dtype=tf.int32))
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)

    return image

# %%
BATCH_SIZE = 32

train_ds = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
train_ds = train_ds.map(
    lambda x, y: load_and_preprocess_image(x, y, training=True),
    num_parallel_calls=tf.data.AUTOTUNE
)
train_ds = train_ds.shuffle(buffer_size=1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((test_paths, test_labels))
test_ds = test_ds.map(
    lambda x, y: load_and_preprocess_image(x, y, training=False),
    num_parallel_calls=tf.data.AUTOTUNE
)
test_ds = test_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
model = Sequential()

model.add( Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[RED_IMG_SIZE, RED_IMG_SIZE, 1]) )
model.add( MaxPool2D() )

model.add( Conv2D(filters=64,kernel_size=3,activation='relu') )
model.add( MaxPool2D() )

model.add( Conv2D(filters=128,kernel_size=3,activation='relu') )
model.add( MaxPool2D() )

model.add(Flatten())
model.add( Dense(units=128,activation='relu') )

model.add( Dense(units= len(classes) ,activation='softmax') )

model.compile(optimizer = Adam(learning_rate=0.001), loss = 'categorical_crossentropy',  metrics=["accuracy"])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "/content/cnn_best.keras",
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
        save_freq="epoch",   # ✅ ensure it checks every epoch
        verbose=1
    )
]

# %%
model.fit(x = train_ds, validation_data = test_ds, epochs = 40, callbacks=callbacks)
# Out:
# Epoch 1/40
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4488 - loss: 1.1647
# Epoch 1: val_accuracy improved from None to 0.70938, saving model to /content/cnn_best.keras
#
# Epoch 1: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 31s 94ms/step - accuracy: 0.5702 - loss: 0.9647 - val_accuracy: 0.7094 - val_loss: 0.7310
# Epoch 2/40
# 176/179 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7389 - loss: 0.6286
# Epoch 2: val_accuracy improved from 0.70938 to 0.75820, saving model to /content/cnn_best.keras
#
# Epoch 2: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.7577 - loss: 0.5986 - val_accuracy: 0.7582 - val_loss: 0.5787
# Epoch 3/40
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8066 - loss: 0.4781
# Epoch 3: val_accuracy improved from 0.75820 to 0.80931, saving model to /content/cnn_best.keras
#
# Epoch 3: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 22s 83ms/step - accuracy: 0.8132 - loss: 0.4701 - val_accuracy: 0.8093 - val_loss: 0.4926
# Epoch 4/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8524 - loss: 0.3687
# Epoch 4: val_accuracy improved from 0.80931 to 0.82914, saving model to /content/cnn_best.keras
#
# Epoch 4: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.8631 - loss: 0.3510 - val_accuracy: 0.8291 - val_loss: 0.4862
# Epoch 5/40
# 176/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9042 - loss: 0.2507
# Epoch 5: val_accuracy improved from 0.82914 to 0.84134, saving model to /content/cnn_best.keras
#
# Epoch 5: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9042 - loss: 0.2554 - val_accuracy: 0.8413 - val_loss: 0.4584
# Epoch 6/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9301 - loss: 0.1952
# Epoch 6: val_accuracy improved from 0.84134 to 0.87490, saving model to /content/cnn_best.keras
#
# Epoch 6: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9371 - loss: 0.1743 - val_accuracy: 0.8749 - val_loss: 0.3894
# Epoch 7/40
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9524 - loss: 0.1297
# Epoch 7: val_accuracy improved from 0.87490 to 0.87567, saving model to /content/cnn_best.keras
#
# Epoch 7: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 71ms/step - accuracy: 0.9562 - loss: 0.1205 - val_accuracy: 0.8757 - val_loss: 0.3989
# Epoch 8/40
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9726 - loss: 0.0860
# Epoch 8: val_accuracy improved from 0.87567 to 0.87948, saving model to /content/cnn_best.keras
#
# Epoch 8: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9687 - loss: 0.0988 - val_accuracy: 0.8795 - val_loss: 0.3987
# Epoch 9/40
# 178/179 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9749 - loss: 0.0733
# Epoch 9: val_accuracy did not improve from 0.87948
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 21s 73ms/step - accuracy: 0.9755 - loss: 0.0736 - val_accuracy: 0.8780 - val_loss: 0.5101
# Epoch 10/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9866 - loss: 0.0465
# Epoch 10: val_accuracy improved from 0.87948 to 0.88558, saving model to /content/cnn_best.keras
#
# Epoch 10: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.9849 - loss: 0.0517 - val_accuracy: 0.8856 - val_loss: 0.4790
# Epoch 11/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9889 - loss: 0.0368
# Epoch 11: val_accuracy improved from 0.88558 to 0.88863, saving model to /content/cnn_best.keras
#
# Epoch 11: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 72ms/step - accuracy: 0.9895 - loss: 0.0379 - val_accuracy: 0.8886 - val_loss: 0.5103
# Epoch 12/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9828 - loss: 0.0584
# Epoch 12: val_accuracy did not improve from 0.88863
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 76ms/step - accuracy: 0.9842 - loss: 0.0550 - val_accuracy: 0.8658 - val_loss: 0.5875
# Epoch 13/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9877 - loss: 0.0387
# Epoch 13: val_accuracy did not improve from 0.88863
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - accuracy: 0.9893 - loss: 0.0381 - val_accuracy: 0.8863 - val_loss: 0.5342
# Epoch 14/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9932 - loss: 0.0291
# Epoch 14: val_accuracy improved from 0.88863 to 0.89092, saving model to /content/cnn_best.keras
#
# Epoch 14: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 21s 73ms/step - accuracy: 0.9918 - loss: 0.0336 - val_accuracy: 0.8909 - val_loss: 0.4640
# Epoch 15/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9937 - loss: 0.0292
# Epoch 15: val_accuracy improved from 0.89092 to 0.89245, saving model to /content/cnn_best.keras
#
# Epoch 15: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 72ms/step - accuracy: 0.9919 - loss: 0.0320 - val_accuracy: 0.8924 - val_loss: 0.4814
# Epoch 16/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9926 - loss: 0.0231
# Epoch 16: val_accuracy did not improve from 0.89245
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 72ms/step - accuracy: 0.9911 - loss: 0.0303 - val_accuracy: 0.8749 - val_loss: 0.5993
# Epoch 17/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9933 - loss: 0.0240
# Epoch 17: val_accuracy improved from 0.89245 to 0.89474, saving model to /content/cnn_best.keras
#
# Epoch 17: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 21s 73ms/step - accuracy: 0.9928 - loss: 0.0247 - val_accuracy: 0.8947 - val_loss: 0.5229
# Epoch 18/40
# 176/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9922 - loss: 0.0271
# Epoch 18: val_accuracy did not improve from 0.89474
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9883 - loss: 0.0434 - val_accuracy: 0.8825 - val_loss: 0.5080
# Epoch 19/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9952 - loss: 0.0182
# Epoch 19: val_accuracy did not improve from 0.89474
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 72ms/step - accuracy: 0.9939 - loss: 0.0231 - val_accuracy: 0.8833 - val_loss: 0.6020
# Epoch 20/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9907 - loss: 0.0395
# Epoch 20: val_accuracy improved from 0.89474 to 0.90465, saving model to /content/cnn_best.keras
#
# Epoch 20: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9925 - loss: 0.0312 - val_accuracy: 0.9047 - val_loss: 0.4529
# Epoch 21/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9930 - loss: 0.0246
# Epoch 21: val_accuracy improved from 0.90465 to 0.90847, saving model to /content/cnn_best.keras
#
# Epoch 21: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.9923 - loss: 0.0302 - val_accuracy: 0.9085 - val_loss: 0.4157
# Epoch 22/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9943 - loss: 0.0199
# Epoch 22: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9932 - loss: 0.0262 - val_accuracy: 0.8879 - val_loss: 0.4769
# Epoch 23/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9848 - loss: 0.0588
# Epoch 23: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 72ms/step - accuracy: 0.9900 - loss: 0.0397 - val_accuracy: 0.8917 - val_loss: 0.5541
# Epoch 24/40
# 176/179 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9960 - loss: 0.0204
# Epoch 24: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9944 - loss: 0.0253 - val_accuracy: 0.8902 - val_loss: 0.4645
# Epoch 25/40
# 176/179 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9954 - loss: 0.0137
# Epoch 25: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9949 - loss: 0.0187 - val_accuracy: 0.8924 - val_loss: 0.5189
# Epoch 26/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9959 - loss: 0.0154
# Epoch 26: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 72ms/step - accuracy: 0.9960 - loss: 0.0152 - val_accuracy: 0.9001 - val_loss: 0.5394
# Epoch 27/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9948 - loss: 0.0178
# Epoch 27: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9928 - loss: 0.0240 - val_accuracy: 0.8833 - val_loss: 0.6866
# Epoch 28/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9912 - loss: 0.0377
# Epoch 28: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 16s 78ms/step - accuracy: 0.9925 - loss: 0.0319 - val_accuracy: 0.8940 - val_loss: 0.5510
# Epoch 29/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9965 - loss: 0.0137
# Epoch 29: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9954 - loss: 0.0171 - val_accuracy: 0.8986 - val_loss: 0.5236
# Epoch 30/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9962 - loss: 0.0145
# Epoch 30: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9937 - loss: 0.0253 - val_accuracy: 0.8902 - val_loss: 0.5405
# Epoch 31/40
# 176/179 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9904 - loss: 0.0321
# Epoch 31: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 21s 70ms/step - accuracy: 0.9916 - loss: 0.0257 - val_accuracy: 0.9077 - val_loss: 0.4355
# Epoch 32/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9970 - loss: 0.0137
# Epoch 32: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.9965 - loss: 0.0150 - val_accuracy: 0.9024 - val_loss: 0.4981
# Epoch 33/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9978 - loss: 0.0095
# Epoch 33: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.9944 - loss: 0.0234 - val_accuracy: 0.9031 - val_loss: 0.4138
# Epoch 34/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9927 - loss: 0.0189
# Epoch 34: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 72ms/step - accuracy: 0.9933 - loss: 0.0231 - val_accuracy: 0.8963 - val_loss: 0.4788
# Epoch 35/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9963 - loss: 0.0194
# Epoch 35: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9960 - loss: 0.0193 - val_accuracy: 0.8986 - val_loss: 0.5114
# Epoch 36/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9984 - loss: 0.0109
# Epoch 36: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 72ms/step - accuracy: 0.9981 - loss: 0.0099 - val_accuracy: 0.9016 - val_loss: 0.5610
# Epoch 37/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9991 - loss: 0.0041
# Epoch 37: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 20s 72ms/step - accuracy: 0.9981 - loss: 0.0075 - val_accuracy: 0.8818 - val_loss: 0.6905
# Epoch 38/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9965 - loss: 0.0144
# Epoch 38: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - accuracy: 0.9977 - loss: 0.0095 - val_accuracy: 0.8986 - val_loss: 0.5634
# Epoch 39/40
# 177/179 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9962 - loss: 0.0233
# Epoch 39: val_accuracy did not improve from 0.90847
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - accuracy: 0.9965 - loss: 0.0157 - val_accuracy: 0.8932 - val_loss: 0.5976
# Epoch 40/40
# 176/179 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9871 - loss: 0.0355
# Epoch 40: val_accuracy improved from 0.90847 to 0.90999, saving model to /content/cnn_best.keras
#
# Epoch 40: finished saving model to /content/cnn_best.keras
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 21s 71ms/step - accuracy: 0.9926 - loss: 0.0238 - val_accuracy: 0.9100 - val_loss: 0.4537

# %%
y_pred = model.predict(test_ds)
y_pred = np.argmax(y_pred,axis=1)
y_test = np.argmax(test_labels,axis=1)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9099923722349351

# %%
cm_df = pd.DataFrame(confusion_matrix(y_test,y_pred))
cm_df.columns = classes
cm_df['class'] = classes
cm_df.set_index('class')
# Out:
#             glioma  meningioma  pituitary  notumor
# class
# glioma         254          41          5        0
# meningioma      16         261         17       12
# pituitary        8           4        288        0
# notumor          1          13          1      390

# %% [markdown]
# Step 3: Visualize (IMPORTANT 🔥)

# %%
def visualize_results(n,source='test'):
    for _ in range(n):
        if source == 'test':
            img_paths = test_paths
            expected_classes = test_labels
        else:
            img_paths = train_paths
            expected_classes = train_labels

        img_pick = random.randint(0,len(img_paths)-1)

        img_path = img_paths[img_pick]
        img_class_expected = np.argmax(expected_classes,axis=1)[img_pick]
        img, _ = load_and_preprocess_image(img_path, label=None, training=False)
        img_batch = tf.expand_dims(img, axis=0)
        class_probs = model.predict(img_batch)
        pred_class_idx = tf.argmax(class_probs[0]).numpy()

        # Load the image for visualization
        raw_img = tf.io.read_file(img_path)
        raw_img = tf.image.decode_jpeg(raw_img, channels=3)
        raw_img = raw_img.numpy()

        fig, ax = plt.subplots(1)
        ax.imshow(raw_img)
        ax.grid(False)

        ax.set_title(f"Predicted: {classes[pred_class_idx]} ; Expected: {classes[img_class_expected]}")
        plt.axis('off')
        plt.show()

# %%
visualize_results(3,source='test')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %% [markdown]
# # final -> unet + cnn

# %% [markdown]
# # DOWNLOAD MODELS FROM COLAB

# %%
from google.colab import files

files.download("/content/unet_best.keras")
files.download("/content/cnn_best.keras")

# %%
def full_pipeline(img_path, true_label=None):

    # =========================
    # STEP 1: PREPROCESS for U-NET (256, grayscale)
    # =========================
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (SEG_IMG_SIZE, SEG_IMG_SIZE))
    img = img / 255.0
    img = np.expand_dims(img, axis=-1)   # (256,256,1)

    # =========================
    # STEP 2: U-NET MASK
    # =========================
    pred = unet_model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    mask = (pred > 0.5).astype(np.uint8)

    # =========================
    # STEP 3: APPLY MASK
    # =========================
    masked_img = img * mask

    # =========================
    # STEP 4: PREPARE FOR CNN (USE ORIGINAL IMAGE)
    # =========================
    cnn_input = cv2.resize(img, (RED_IMG_SIZE, RED_IMG_SIZE))
    cnn_input = np.expand_dims(cnn_input, axis=0)

    # =========================
    # STEP 5: CNN PREDICTION
    # =========================
    pred = cnn_model.predict(cnn_input, verbose=0)[0]
    class_idx = np.argmax(pred)
    confidence = pred[class_idx]

    pred_class = classes[class_idx]

    # =========================
    # PRINT OUTPUT
    # =========================
    print("\nImage:", img_path)
    if true_label:
        print("Actual:", true_label)

    print(f"Prediction: {pred_class} ({confidence:.2f})")

    if true_label:
        print("Correct ✅" if pred_class == true_label else "Wrong ❌")

    # =========================
    # SHOW IMAGES
    # =========================
    plt.figure(figsize=(12,4))

    plt.subplot(1,3,1)
    plt.imshow(img.squeeze(), cmap='gray')
    plt.title("Input")

    plt.subplot(1,3,2)
    plt.imshow(mask.squeeze(), cmap='gray')
    plt.title("Mask")

    plt.subplot(1,3,3)
    plt.imshow(masked_img.squeeze(), cmap='gray')
    plt.title(f"Pred: {pred_class}")

    plt.show()

# %%
def test_random_image():
    all_data = []

    for label in classes:
        folder = os.path.join(test_dir, label)
        for file in os.listdir(folder):
            all_data.append((os.path.join(folder, file), label))

    img_path, label = random.choice(all_data)

    full_pipeline(img_path, true_label=label)

# %%
test_random_image()
# Out:
# Image: /content/archive (5)/DATASET/classification/Testing/glioma/enh_Te-gl_0184.jpg
# Actual: glioma
# Prediction: glioma (1.00)
# Correct ✅

# %%
def evaluate_pipeline():

    correct = 0
    total = 0

    for label in classes:
        folder = os.path.join(test_dir, label)

        for file in os.listdir(folder):
            img_path = os.path.join(folder, file)

            # =========================
            # PREPROCESS (same as pipeline)
            # =========================
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, (SEG_IMG_SIZE, SEG_IMG_SIZE))
            img = img / 255.0
            img = np.expand_dims(img, axis=-1)

            # =========================
            # U-NET (mask)
            # =========================
            pred_mask = unet_model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
            mask = (pred_mask > 0.5).astype(np.uint8)

            # =========================
            # APPLY MASK (optional, only for visualization)
            # =========================
            masked_img = img * mask

            # =========================
            # CNN INPUT (IMPORTANT: original image)
            # =========================
            cnn_input = cv2.resize(img, (RED_IMG_SIZE, RED_IMG_SIZE))
            cnn_input = np.expand_dims(cnn_input, axis=0)

            # =========================
            # PREDICTION
            # =========================
            pred = cnn_model.predict(cnn_input, verbose=0)[0]
            pred_class = classes[np.argmax(pred)]

            # =========================
            # ACCURACY COUNT
            # =========================
            if pred_class == label:
                correct += 1

            total += 1

    accuracy = correct / total

    print(f"\nPipeline Accuracy: {accuracy:.4f}")

# %%
evaluate_pipeline()
# Out:
# Pipeline Accuracy: 0.8940
